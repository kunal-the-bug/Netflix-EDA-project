# %% [markdown]
# # Importing important libararies.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
# Accessing data from csv file in the form of DataFrame

df = pd.read_csv("C:/Users/Admin/Downloads/netflix_titles.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#checking Null values.

df.isnull(). sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#checking column types
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# Filling the missing values with the method of Fillna.

df.director.fillna('Unknown',inplace=True)
df.cast.fillna('Unknown',inplace=True)
df.country.fillna('Unknown',inplace=True)
df.date_added.fillna('Unknown',inplace=True)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
  df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          4
# duration        3
# listed_in       0
# description     0
# dtype: int64

# %%
# droping the rest of the null values with the method of Dropna.

df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8800 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8800 non-null   object
#  1   type          8800 non-null   object
#  2   title         8800 non-null   object
#  3   director      8800 non-null   object
#  4   cast          8800 non-null   object
#  5   country       8800 non-null   object
#  6   date_added    8800 non-null   object
#  7   release_year  8800 non-null   int64
#  8   rating        8800 non-null   object
#  9   duration      8800 non-null   object
#  10  listed_in     8800 non-null   object
#  11  description   8800 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 893.8+ KB

# %%
# checking the duplicate values in dataset.

df.duplicated().any().sum()
# Out:
# 0

# %%
df.type.value_counts()
# Out:
# type
# Movie      6126
# TV Show    2674
# Name: count, dtype: int64

# %% [markdown]
# # Data Visualisation

# %%
# Explore Movies vs TV Shows
# Pie Plot

plt.pie(x=df.type.value_counts(),labels=df.type.value_counts().index,colors=['red','grey'],
       autopct='%1.1f%%',shadow=True,explode=(0,0.07))
plt.legend(loc='upper right')

# %% [markdown]
# # There is a Greater Number of Movies Available than TV Shows on Netflix

# %%
# Count the occurrences of each genre.
df.listed_in.value_counts()
# Out:
# listed_in
# Dramas, International Movies                          362
# Documentaries                                         359
# Stand-Up Comedy                                       334
# Comedies, Dramas, International Movies                274
# Dramas, Independent Movies, International Movies      252
#                                                      ...
# Kids' TV, TV Action & Adventure, TV Dramas              1
# TV Comedies, TV Dramas, TV Horror                       1
# Children & Family Movies, Comedies, LGBTQ Movies        1
# Kids' TV, Spanish-Language TV Shows, Teen TV Shows      1
# Cult Movies, Dramas, Thrillers                          1
# Name: count, Length: 514, dtype: int64

# %%
# Extract the 'listed_in' column (which contains genre information)
genres = df['listed_in'].str.split(',').explode().str.strip()

# %%
genre_counts = genres.value_counts()

# %%
# Visualize the distribution of content over different genres
plt.figure(figsize=(12, 8))
genre_counts.plot(kind='bar',color='green')
plt.title('Distribution of Netflix Content over different Genre')
plt.xlabel('Genres')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %%
# Extracting Top ten Genres on netflix.
genre_counts.head(10)
# Out:
# listed_in
# International Movies        2752
# Dramas                      2426
# Comedies                    1674
# International TV Shows      1350
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    763
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64

# %%
# ploting a barplot for top 10 Genres on Netflix
plt.figure(figsize=(8,5))
sns.barplot(x=genre_counts.head(10).values,y=genre_counts.head(10).index,palette='dark')
plt.xlabel('Number of titles')
plt.ylabel('Genres')
plt.title('Top 10 Genres on Netflix')
# Out:
# Text(0.5, 1.0, 'Top 10 Genres on Netflix')

# %% [markdown]
# # NUMBER OF TITLES RELEASED BY YEARS

# %%
plt.figure(figsize=(11,4))
plt.bar(df.release_year.value_counts().index,df.release_year.value_counts())
plt.xlabel('Releasing years')
plt.ylabel('No. of movies & Tv show')
# Out:
# Text(0, 0.5, 'No. of movies & Tv show')

# %% [markdown]
# # Release Year

# %%
# checking last ten year data of TV Show & Movies

last_ten_year=df[["type","release_year"]]
last_ten_year=last_ten_year[last_ten_year["release_year"] >=2012]
last_ten_year
# Out:
#          type  release_year
# 0       Movie          2020
# 1     TV Show          2021
# 2     TV Show          2021
# 3     TV Show          2021
# 4     TV Show          2021
# ...       ...           ...
# 8798    Movie          2014
# 8800  TV Show          2012
# 8801    Movie          2015
# 8803  TV Show          2018
# 8806    Movie          2015
#
# [7087 rows x 2 columns]

# %%
last_ten_year.groupby("release_year")["type"].value_counts()
# Out:
# release_year  type
# 2012          Movie      173
#               TV Show     64
# 2013          Movie      225
#               TV Show     62
# 2014          Movie      264
#               TV Show     88
# 2015          Movie      396
#               TV Show    161
# 2016          Movie      658
#               TV Show    244
# 2017          Movie      765
#               TV Show    265
# 2018          Movie      767
#               TV Show    380
# 2019          Movie      633
#               TV Show    397
# 2020          Movie      517
#               TV Show    436
# 2021          TV Show    315
#               Movie      277
# Name: count, dtype: int64

# %%
last_ten_year_df =last_ten_year.groupby("release_year")["type"].size().reset_index()
last_ten_year_df = pd.DataFrame(last_ten_year_df)
last_ten_year_df
# Out:
#    release_year  type
# 0          2012   237
# 1          2013   287
# 2          2014   352
# 3          2015   557
# 4          2016   902
# 5          2017  1030
# 6          2018  1147
# 7          2019  1030
# 8          2020   953
# 9          2021   592

# %%
last_ten_year_df.rename(columns={"type" : "Total Content"},inplace=True)
last_ten_year_df
# Out:
#    release_year  Total Content
# 0          2012            237
# 1          2013            287
# 2          2014            352
# 3          2015            557
# 4          2016            902
# 5          2017           1030
# 6          2018           1147
# 7          2019           1030
# 8          2020            953
# 9          2021            592

# %%
# create a countplot of last ten year data of TV shows & Movies.

plt.figure(figsize=(7,4))
sns.countplot(x="release_year", data=last_ten_year, hue="type")
plt.xticks(rotation=45)
plt.show()

# %%
# checking in which year the maximum number of movies were released.

df.release_year.value_counts().sort_values
# Out:
# <bound method Series.sort_values of release_year
# 2018    1147
# 2017    1030
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: count, Length: 74, dtype: int64>

# %%
# create a countplot.
plt.figure(figsize=(7,4))
plt.title('Number of Titles Released by Year')
sns.countplot(x="release_year",data=last_ten_year,palette="viridis")
# Out:
# <Axes: title={'center': 'Number of Titles Released by Year'}, xlabel='release_year', ylabel='count'>

# %% [markdown]
# # Rating

# %%
df.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
# Changing rating categories name

New = { 'TV-PG': 'Parental Guidance',
    'TV-MA': 'Mature Audience',
    'TV-Y7-FV': 'Teens',
    'TV-Y7': 'Teens',
    'TV-14': 'Teens',
    'R': 'Mature Audience',
    'TV-Y': 'General Audience',
    'NR': 'Mature Audience',
    'PG-13': 'Teens',
    'TV-G': 'General Audience',
    'PG': 'Teens',
    'G': 'General Audience',
    'UR': 'Mature Audience',
    'NC-17': 'Mature Audience'}

df["rating"] = df['rating'].replace(New)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['rating'].value_counts()
# Out:
# rating
# Mature Audience      4092
# Teens                3277
# Parental Guidance     863
# General Audience      568
# Name: count, dtype: int64

# %%
# creating a countplot based on ratings.
plt.figure(figsize=(10,7))
sns.countplot(x="rating",data=df,palette="viridis")
plt.title("Count of Rating by Movie and Shows")
# Out:
# Text(0.5, 1.0, 'Count of Rating by Movie and Shows')

# %% [markdown]
# # It shows that Netflix has the more content for Mature Audience

# %% [markdown]
# # Checking the length of movies or episodes.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8800 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8800 non-null   object
#  1   type          8800 non-null   object
#  2   title         8800 non-null   object
#  3   director      8800 non-null   object
#  4   cast          8800 non-null   object
#  5   country       8800 non-null   object
#  6   date_added    8800 non-null   object
#  7   release_year  8800 non-null   int64
#  8   rating        8800 non-null   object
#  9   duration      8800 non-null   object
#  10  listed_in     8800 non-null   object
#  11  description   8800 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 893.8+ KB

# %%
df['duration'] = df['duration'].str.extract('(\d+)').astype(float)# Convert 'duration' to numeric values.
sns.histplot(df['duration'], bins=30, color='y', edgecolor='black')

plt.xlabel('Duration (minutes)')
plt.ylabel('Number of Titles')
plt.title('Distribution of Movie/Episode Durations')
plt.show()

# %% [markdown]
# # Country

# %%
# checking the value counts of top ten content production countries

df.country.value_counts().head(10)
# Out:
# country
# United States     2815
# India              972
# Unknown            830
# United Kingdom     419
# Japan              244
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %%
top_10_country = df.country.value_counts().head(10)
top_10_country= pd.DataFrame(top_10_country)

top_10_country
# Out:
#                 count
# country
# United States    2815
# India             972
# Unknown           830
# United Kingdom    419
# Japan             244
# South Korea       199
# Canada            181
# Spain             145
# France            124
# Mexico            110

# %%
# creating a horizontal barplot of Top 10 content production countries

plt.figure(figsize=(11,5))
sns.barplot(x=df.country.value_counts()[:10].values , y=df.country.value_counts()[:10].index,palette='cubehelix')
plt.xlabel('Number of titles')
plt .title('Top 10 content production countries')
# Out:
# Text(0.5, 1.0, 'Top 10 content production countries')

# %% [markdown]
# # Trends over Time.

# %%
#Ensure 'release_year' is in numeric format
df['release_year'] = pd.to_numeric(df['release_year'], errors='coerce')

# %%
# Drop rows with missing release_year
df = df.dropna(subset=['release_year'])

# %%
#Group by release year and calculate the average duration
yearly_avg_duration = df.groupby('release_year')['duration'].mean()

# %%
#Plot the trends over time
plt.figure(figsize=(12, 6))

plt.plot(yearly_avg_duration.index, yearly_avg_duration.values,color='brown')

plt.xlabel('Release Year')
plt.ylabel('Average Duration ( In minutes)')
plt.title('Average Movie/Episode Duration Over Time')
plt.grid(True)
plt.show()

# %% [markdown]
# # Content Evolution over Time

# %%
content_by_year = df['release_year'].value_counts().sort_index()

# %%
plt.figure(figsize=(10, 4))
plt.plot(content_by_year.index, content_by_year.values, marker='o', color='k')
plt.xlabel('Year')
plt.ylabel('Number of Titles')
plt.title('Evolution of Netflix Content Over Time')
plt.grid()
plt.show()
